# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("Datasets/finalData.csv")
type(df)
new_df = pd.DataFrame()

# %%
l = []
k = 0
count = 0
for i in df['description']:
    if 'Register now' in i:
        print(k, df.description[k])
        #count += 1
        #l.append(k);
       # new_df = df.drop(df.index[k])   
    k += 1
print(l)
# Out:
# 10724 The future is now. Get ready for #GalaxyZFold2 – the phone that is designed to change the shape of the future. Which feature are you most excited about? Register now: https://bit.ly/2YQHu2b #Samsung
# 10745 The future is now. Get ready for #GalaxyZFold2 – the phone that is designed to change the shape of the future. Which feature are you most excited about? Register now: https://bit.ly/2YQHu2b #Samsung
# 10766 The future is now. Get ready for #GalaxyZFold2 – the phone that is designed to change the shape of the future. Which feature are you most excited about? Register now: https://bit.ly/2YQHu2b #Samsung
# 10787 The future is now. Get ready for #GalaxyZFold2 – the phone that is designed to change the shape of the future. Which feature are you most excited about? Register now: https://bit.ly/2YQHu2b #Samsung
# ...

# %%
new_df.to_csv('real_final_data.csv')
