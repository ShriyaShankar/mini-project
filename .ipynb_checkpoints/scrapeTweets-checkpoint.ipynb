# %%
import GetOldTweets3 as got
import pandas as pd

text_query = 'BWSSB'
count = 100

tweet_criteria = got.manager.TweetCriteria().setQuerySearch(text_query).setMaxTweets(count)

tweets = got.manager.TweetManager.getTweets(tweet_criteria)
#print(tweets)
reqd_tweets = [[tweet.date, tweet.text] for tweet in tweets]
#print(reqd_tweets)
bwssb = pd.DataFrame(reqd_tweets)

# %%
text_query = '#bbmp'

tweet_criteria = got.manager.TweetCriteria().setQuerySearch(text_query).setMaxTweets(count)

tweets = got.manager.TweetManager.getTweets(tweet_criteria)
#print(tweets)
reqd_tweets = [[tweet.date, tweet.text] for tweet in tweets]
print(reqd_tweets)
bbmp = pd.DataFrame(reqd_tweets)
# Out:
# [[datetime.datetime(2020, 9, 4, 15, 23, 55, tzinfo=datetime.timezone.utc), 'Não vou perder meu tempo com pessoas que sequer sabem o que é respeito às opiniões divergentes. Tenho a MINHA OPINIÃO e ninguém vai me catequizar ou me doutrinar aqui Felipão SIM. #BBMP'], [datetime.datetime(2020, 9, 1, 15, 45, tzinfo=datetime.timezone.utc), 'The future is now. Get ready for #GalaxyZFold2 – the phone that is designed to change the shape of the future. Which feature are you most excited about? Register now: https://bit.ly/2YQHu2b #Samsung'], [datetime.datetime(2020, 9, 4, 15, 14, 56, tzinfo=datetime.timezone.utc), '@BBMPSWMSplComm please take action sir @BBMPCOMM #bbmp @BBMP_MAYOR @WFRising'], [datetime.datetime(2020, 9, 4, 15, 9, 57, tzinfo=datetime.timezone.utc), 'Infelizmente o esquema de jogo do Bahia não favorecia o estilo de jogo de Fernandão... mas nunca faltou entrega e profissionalismo ao jogador. Continuará sendo ídolo pelo que fez no Bahia no passado e no presente. #BBMP #SocioDigital'], [datetime.datetime(2020, 9, 4, 15, 2, 46, tzinfo=datetime.timezone.utc), 'Aff tb odeio isso! E vc é de cajacity? A maior parte de minha vida foi na 4 rsrsrs #BBMP'], [datetime.datetime(2020, 9, 4, 14, 51, 39, tzinfo=datetime.timezone.utc), ' Último treino antes da viagem a Porto Alegre aconteceu nesta manhã em Pituaço #BBMP '], [datetime.datetime(2020, 9, 4, 14, 47, 52, tzinfo=datetime.timezone.utc), 'Esse é um cara que tem TODO meu respeito. Critiquei? Sim. Mas o respeito e admiração pela seu carinho e dedicação ao Esporte Clube Bahia são maiores que qualquer fato negativo. Desejo muito sucesso do mundo. #BBMP '], [datetime.datetime(2020, 9, 4, 14, 47, 34, tzinfo=datetime